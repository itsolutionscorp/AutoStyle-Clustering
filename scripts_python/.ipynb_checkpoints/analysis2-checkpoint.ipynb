# %%
import sys
import os
import glob
import re
import ast
import betterast
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from scipy.stats import kruskal
from scipy.stats import f_oneway
sys.path.insert(0, os.path.abspath('../featurization'))
sys.path.insert(0, os.path.abspath('featurization'))
from individual_features import abc_score
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#!/usr/bin/env python
def get_node_label(node):
    '''
    Get the label of a python ast object.
    '''
    return str(type(node)).replace("<class '_ast.","").replace("'>","")

def build_tree(node, ast_node, functions):
    '''
    Recursively construct a Node object out of a python ast object.
    '''
    if isinstance(ast_node, str) or isinstance(ast_node, int) or (ast_node == None):
        return node
    n = [i for i in ast.iter_child_nodes(ast_node)]
    for i,kid in enumerate(n):
        label = get_node_label(kid)
        if 'lineno' in kid._attributes:
            line = kid.lineno
        elif 'lineno' in ast_node._attributes:
            line = ast_node.lineno
        else:
            line = 0
        if label == "FunctionDef":
            name = [r[1] for r in ast.iter_fields(kid) if r[0] == 'name'][0]
            label = "FunctionDef: " + name
        if i==0 and node.label[0:4] == "Call" and 'func' in dir(ast_node):
            label = [r[1] for r in ast.iter_fields(kid) if r[0] == 'attr' or r[0] == 'id'][0]
        if label in functions:
            label = functions[label]
        kidNode = betterast.Node(label + "::" + str(line))
        node.addkid(kidNode)
        build_tree(kidNode, kid, functions)
    return node

def generate_python_ast(code):
    '''
    Generate an Node object representing an ast for a python file.
    '''
    try:
        ast_node = ast.parse(code, mode='exec')
    except Exception as e:
        print "FAILED: to generate ast: " + str(e)
        return
    ast_node = ast.fix_missing_locations(ast_node)
    if 'lineno' in ast_node._attributes:
        b_node = betterast.Node(get_node_label(ast_node) + "::" + ast_node.lineno)
    else:
        b_node = betterast.Node(get_node_label(ast_node))
    tree = build_tree(b_node,ast_node,{})
    return tree

def get_score(code): 
    ast = generate_python_ast(code)
    num_lines = len(code.split("\n"))
    return abc_score(ast, num_lines)
    
def clean_code(string):
    string = re.sub(re.compile("\r\n"), "\n", string)
    string = re.sub(re.compile("\n\n"), "\n", string)
    string = re.sub(re.compile("#.*?\n") ,"\n" ,string) # remove all occurance singleline comments (//COMMENT\n ) from string
    string = re.sub(re.compile("[\n\t ]*#.*?$") ,"" ,string) # remove all occurance singleline comments (//COMMENT\n ) from string
    string = re.sub(re.compile("\n[\t ]*\n"), "\n", string) #remove occurances of empty lines
    string = re.sub(re.compile("\n[\t ]*\n"), "\n", string)
    return string.rstrip("\n\t ")

# %%
control = {}
auto = {}
home_dir = ".."
files = glob.glob(home_dir + "/intervention/results/*")
for f in files:
    # example filename for experiment group: ../intervention/results/111101_1447284327_539_4_5.73.py
    if f.split("/")[-1].startswith("control"):
        contents = open(f).read()
        code = clean_code(contents)
        score = get_score(code)[0][0]
        spl = f.split("/")[-1].split("_")
        if len(spl) == 5:
            student, timestamp, timetaken, flog = f.split("_")[1:]
        else:
            print "control split failure ", f
        control[f.split("/")[-1]] = [student, timestamp, timetaken, score, code]
    else:
        contents = open(f).read()
        code, pos = contents.split('Positive Hints\n')
        pos, neg = pos.split('Negative Hints\n')
        neg, approach = neg.split('Approach Hints\n')
        approach, skeleton = approach.split("Skeleton\n")
        approach = approach.strip("\n")
        skeleton = skeleton.strip("\n")
        pos = pos.strip("\n")
        neg = neg.strip("\n")
        code = clean_code(code)
        score = get_score(code)[0][0]
        spl = f.split("/")[-1].rstrip(".py").split("_") 
        if len(spl) == 5:
            student, timestamp, timetaken, cluster, flog = spl
        else:
            print "auto split four",f 
            student, timestamp, timetaken, cluster = spl
        auto[f.split("/")[-1]] = [student, timestamp, timetaken, score, code, pos, neg, approach, skeleton, cluster]
# Out:
# auto split four ../intervention/results/111101_1447285124_793_4.py
# auto split four ../intervention/results/111102_1447283734_206_0.py
# auto split four ../intervention/results/111102_1447284044_48_5.py
# auto split four ../intervention/results/111102_1447284872_16_0.py
# auto split four ../intervention/results/111102_1447285135_25_4.py
# auto split four ../intervention/results/111103_1447284328_121_2.py
# auto split four ../intervention/results/111103_1447285581_38_4.py
# auto split four ../intervention/results/111103_1447286361_25_4.py
# auto split four ../intervention/results/111103_1447286394_26_4.py
# auto split four ../intervention/results/111103_1447287289_303_4.py
# auto split four ../intervention/results/111103_1447287326_5_4.py
# auto split four ../intervention/results/111104_1447287725_148_7.py
# auto split four ../intervention/results/111104_1447289080_84_5.py

# %%
control_df = pd.DataFrame.from_dict(data = control, orient="index") # use filename (key of dict) as label
control_df.columns = ["student_id", "timestamp", "time_taken", "flog_score", "code"]
auto_df = pd.DataFrame.from_dict(data = auto,orient="index")
auto_df.columns = ["student_id", "timestamp", "time_taken", "flog_score", "code", "pos_hints", "neg_hint", "approach_hints", "skeleton", "cluster"]

# %%
# assgin each student a sid and add sid column to dataframe
current_newsid = 1 

sid_newsid_dict = {}
auto_newsids = []
for sid in auto_df.student_id:
    if sid not in sid_newsid_dict:
        sid_newsid_dict[sid] = current_newsid
        current_newsid += 1
    auto_newsids.append(sid_newsid_dict[sid])
auto_df["sid"] = pd.Series(auto_newsids, index = auto_df.index) 

control_sid_newsid_dict = {}
control_newsids = []
for sid in control_df.student_id:
    if sid not in control_sid_newsid_dict:
        control_sid_newsid_dict[sid] = current_newsid
        current_newsid += 1
    control_newsids.append(control_sid_newsid_dict[sid])
control_df["sid"] = pd.Series(control_newsids, index = control_df.index)

# %%
autohints = []
asmat = auto_df.as_matrix()
for index in range(asmat.shape[0]):
    if asmat[index, 8] != "":
        autohints.append("skeleton")
    elif asmat[index, 7] != "":
        autohints.append("approach")
    elif asmat[index, 6] != "" or asmat[index, 5] != "":
        autohints.append("auto")
    else:
        autohints.append("none")
auto_df["hints"] = pd.Series(autohints, index = auto_df.index)
# print auto_df.iloc[0]
control_df["hints"] = pd.Series(["none" for i in range(len(control_df))], index = control_df.index)

# %%
def get_sid_f_mapping(dataframe):
    sid_flog = np.array(dataframe[["sid","flog_score"]])
    highest_flog = dict(sid_flog)

    for key, val in sid_flog:
        if val > highest_flog[key]:
            highest_flog[key] = val
    thf = [(v, k) for k, v in highest_flog.iteritems()]
    sorted_thf = sorted(thf)[::-1]
    mapping_sid_f = {}
    jump = min(sorted_thf, key=lambda x: x[1])[1]
    for i,kv in enumerate(sorted_thf):
        mapping_sid_f[int(kv[1])] = int(i+jump)
    
    final = []
    for s in dataframe.sid:
        final.append(mapping_sid_f[s])
    return mapping_sid_f, final

auto_sid_f = get_sid_f_mapping(auto_df)
control_sid_f = get_sid_f_mapping(control_df)

# %%
auto_df["sid"] = pd.Series(auto_sid_f[1], index = auto_df.index)
control_df["sid"] = pd.Series(control_sid_f[1], index = control_df.index)

# %%
auto_df["type"] = pd.Series(["auto" for i in range(len(auto_df))], index = auto_df.index)
control_df["type"] = pd.Series(["control" for i in range(len(control_df))], index = control_df.index)
auto_simple = auto_df[["student_id", "timestamp", "time_taken", "flog_score", "code", "sid", "type", "hints"]]
all_df = pd.concat([auto_simple, control_df], axis=0)
all_df.to_csv("all_df.csv", sep="~")

# %%
control_df.to_csv("control_df.csv", sep="~")
auto_df.to_csv("auto_df.csv", sep="~")

# %% [markdown]
#  # Data Analysis Section

# %%
import pandas as pd
cdf = pd.read_csv("control_df.csv", sep="~", index_col = 0)
adf = pd.read_csv("auto_df.csv", sep="~", index_col = 0)

# %%
from itertools import groupby # need to sort data before using groupby
adict = {}
fdict, ldict = {}, {} # each student's first and last submission

    
def get_first_and_last_sub(corpus):
    sorted_corpus = sorted(corpus, key=lambda s: s[1]) # s[1] is timestamp
    return (sorted_corpus[0], sorted_corpus[-1])
for sid, group in groupby(adf.sort(columns = "sid").values, lambda p:p[10]): # p[10] is sid
    corpus = list(group)
    adict[sid] = corpus
    first, last = get_first_and_last_sub(corpus)
    fdict[sid] = first
    ldict[sid] = last


def compute_mean_flog(corpus):
    return reduce(lambda x, y: x + y[3], corpus, 0) / len(corpus) # y[3] is flog score

fmean = compute_mean_flog(fdict.values())
lmean = compute_mean_flog(ldict.values())
print "mean flog score of auto group's first submissions: ", fmean
print "mean flog score of auto group's last submissions: ", lmean

# for control group
cdict = {}
cfdict, cldict = {}, {}
for sid, group in groupby(cdf.sort(columns = "sid").values, lambda p:p[5]): # p[10] is sid
    corpus = list(group)
    cdict[sid] = corpus
    first, last = get_first_and_last_sub(corpus)
    cfdict[sid] = first
    cldict[sid] = last
    
cfmean = compute_mean_flog(cfdict.values())
clmean = compute_mean_flog(cldict.values())
print "mean flog score of control group's first submissions: ", cfmean
print "mean flog score of control group's last submissions: ", clmean
# Out:
# mean flog score of auto group's first submissions:  11.1622
# mean flog score of auto group's last submissions:  4.0934
# mean flog score of control group's first submissions:  12.3761290323
# mean flog score of control group's last submissions:  8.24064516129

# %%
"""scipy always gives the test statistic as signed. This means that given p and t values 
from a two-tailed test, you would reject the null hypothesis of a greater-than test 
when p/2 < alpha and t > 0, and of a less-than test when p/2 < alpha and t < 0."""
def test_hypothesis(pvalue):
    if pvalue <= 0.025:
        return "reject null hypothesis at 5% sig lvl"
    else:
        return "accept null hypothesis at 5% sig lvl"
    
def test_hypothesis_one_t(pvalue):
    if pvalue/2 <= 0.025:
        return "reject null hypothesis at 5% sig lvl"
    else:
        return "accept null hypothesis at 5% sig lvl" 
    
first = [student[3] for student in fdict.values()]
last = [student[3] for student in ldict.values()]
cfirst = [student[3] for student in cfdict.values()]
clast = [student[3] for student in cldict.values()]
change = sorted(np.array(first) - np.array(last))
cchange = sorted(np.array(cfirst) - np.array(clast))
change_pc = (change/np.array(first))*100
cchange_pc = (cchange/np.array(cfirst))*100
print "treatment", np.mean(change), np.std(change)
print "control", np.mean(cchange), np.std(cchange)
# we want to reject the null hypothesis that they come from the same distribution
# If the p-value is less than or equal to the chosen significance level null hypothesis must be rejected.
print "t-test", ttest_ind(change, cchange, equal_var=False), test_hypothesis_one_t(ttest_ind(change, cchange, equal_var=False)[1])
print "kruskal", kruskal(change, cchange), test_hypothesis(kruskal(change, cchange)[1])
print "anova", f_oneway(change, cchange), test_hypothesis(f_oneway(change, cchange)[1])
print ""


print "treatment pc", np.mean(change_pc), np.std(change_pc)
print "control pc", np.mean(cchange_pc), np.std(cchange_pc)

print "t-test", ttest_ind(change_pc, cchange_pc, equal_var=False), test_hypothesis_one_t(ttest_ind(change, cchange, equal_var=False)[1])
print "kruskal", kruskal(change_pc, cchange_pc), test_hypothesis(kruskal(change_pc, cchange_pc)[1])
print "anova", f_oneway(change_pc, cchange_pc), test_hypothesis(f_oneway(change_pc, cchange_pc)[1])
print ""


plt.hist((cchange, change), normed=True, label=("Control", "Treatment"))
plt.legend(loc='upper right')
plt.xlabel("Total improvement in style score")
plt.ylabel("Frequency (normalized)")
plt.show()


plt.hist((cchange, change), label=("Control", "Treatment"))
plt.legend(loc='upper right')
plt.xlabel("Total improvement in style score")
plt.ylabel("Number of students")

plt.show()

print "t-test", ttest_ind(first, cfirst, equal_var=False), test_hypothesis_one_t(ttest_ind(first, cfirst, equal_var=False)[1])
print "kruskal", kruskal(first, cfirst), test_hypothesis(kruskal(first, cfirst)[1])
print "anova", f_oneway(first, cfirst), test_hypothesis(f_oneway(first, cfirst)[1])
print ""

# plt.hist((cchange_pc, change_pc))
# Out:
# treatment 7.0688 4.91966854168
# control 4.13548387097 3.11497303743
# t-test (array(3.2444994653292176), 0.0017265190012817153) reject null hypothesis at 5% sig lvl
# kruskal (7.2780170559210582, 0.0069803549684539527) reject null hypothesis at 5% sig lvl
# anova (8.6087665448757971, 0.0043776715633879904) reject null hypothesis at 5% sig lvl
#
# treatment pc 109.927198247 163.568956996
# control pc 40.9832310483 38.3521092722
# t-test (array(2.8263181309719205), 0.0064676381028024379) reject null hypothesis at 5% sig lvl
# kruskal (6.6618001555422319, 0.0098501361729007395) reject null hypothesis at 5% sig lvl
# anova (5.1944327749511272, 0.02535867530312752) accept null hypothesis at 5% sig lvl

# %%
# compute improvement per submission

def get_imp_data(ddict):
    imp_dict = {}
    for sid in ddict:
        sorted_corpus = sorted(ddict[sid], key=lambda s: s[1]) # s[1] is timestamp
        imp_list = []
        for i in range(len(sorted_corpus) - 1):
            imp_list.append(sorted_corpus[i+1][3] - sorted_corpus[i][3])
        imp_dict[sid] = imp_list
    return imp_dict

def compute_imp_per_sub(imp_dict):
    all_imp = []
    for sid in imp_dict:
        all_imp += imp_dict[sid]
    all_imp_arr = np.array(all_imp)
    return (np.mean(all_imp_arr), np.std(all_imp_arr)), all_imp_arr

def compute_avg_num_subs(ddict):
    num_subs = []
    for sid in ddict:
        num_subs.append(len(ddict[sid]))
    num_subs_arr = np.array(num_subs)
    return (np.mean(num_subs_arr), np.std(num_subs_arr)), num_subs_arr
    def num_subs2():
        
auto_avg_num_subs, auto_num_subs = compute_avg_num_subs(adict)
control_avg_num_subs, control_num_subs = compute_avg_num_subs(cdict)

print "average number of submissions made by students from auto group: ", auto_avg_num_subs
print "average number of submissions made by students from control group: ", control_avg_num_subs
print "t-test", ttest_ind(auto_num_subs, control_num_subs, equal_var=False), test_hypothesis_one_t(ttest_ind(auto_num_subs, control_num_subs, equal_var=False)[1])
print "kruskal", kruskal(auto_num_subs, control_num_subs), test_hypothesis(kruskal(auto_num_subs, control_num_subs)[1])
print "anova", f_oneway(auto_num_subs, control_num_subs), test_hypothesis(f_oneway(auto_num_subs, control_num_subs)[1])
print ""



auto_imp_dict = get_imp_data(adict)
auto_avg_imp_per_sub, auto_imp_per_sub = compute_imp_per_sub(auto_imp_dict)
control_imp_dict = get_imp_data(cdict)
control_avg_imp_per_sub, control_imp_per_sub = compute_imp_per_sub(control_imp_dict)

print "flog improvement per submission for auto group: ", auto_avg_imp_per_sub
print "flog improvement per submission for control group: ", control_avg_imp_per_sub

print "t-test", ttest_ind(auto_imp_per_sub, control_imp_per_sub, equal_var=False), test_hypothesis_one_t(ttest_ind(auto_imp_per_sub, control_imp_per_sub, equal_var=False)[1])
print "kruskal", kruskal(auto_imp_per_sub, control_imp_per_sub), test_hypothesis(kruskal(auto_imp_per_sub, control_imp_per_sub)[1])
print "anova", f_oneway(auto_imp_per_sub, control_imp_per_sub), test_hypothesis(f_oneway(auto_imp_per_sub, control_imp_per_sub)[1])
print ""

# %%
cdf

# %%
plt.hist(cdf.flog_score)
# Out:
# (array([ 71.,  23.,  15.,  36.,  36.,  40.,  12.,   1.,   1.,   4.]),
#  array([  2.41 ,   4.342,   6.274,   8.206,  10.138,  12.07 ,  14.002,
#          15.934,  17.866,  19.798,  21.73 ]),
#  <a list of 10 Patch objects>)

# %%
cdf2 = cdf.sort(columns = "flog_score")

# %%
cdf3 = cdf2.drop_duplicates(subset="student_id")

# %%
o = 1
print cdf3.iloc[o].code, cdf3.iloc[o].flog_score
# Out:
# def num_common_letters(goal_word, guess):
# 	return len(set(goal_word) & set(guess)) 2.41

# %%
cdf3
# Out:
#                                         student_id   timestamp  time_taken  \
# control_1114013_1447540598_291_2.41.py     1114013  1447540598         291
# control_1114018_1447545535_7_2.41.py       1114018  1447545535           7
# control_111712_1447799453_409_2.41.py       111712  1447799453         409
# control_111902_1447990994_29_3.0.py         111902  1447990994          29
# control_120723_1449536516_19_3.0.py         120723  1449536516          19
# control_120712_1449531512_113_2.61.py       120712  1449531512         113
# control_120722_1449535877_103_2.61.py       120722  1449535877         103
# control_120713_1449531544_24_3.71.py        120713  1449531544          24
# control_120102_1449528822_18_4.1.py         120102  1449528822          18
# control_120802_1449613833_121_6.87.py       120802  1449613833         121
# control_120710_1449531247_183_7.2.py        120710  1449531247         183
# control_120801_1449613421_121_6.99.py       120801  1449613421         121
# control_1114016_1447542994_530_8.05.py     1114016  1447542994         530
# control_111904_1447993241_112_7.5.py        111904  1447993241         112
# control_1114012_1447544396_845_8.76.py     1114012  1447544396         845
# control_111915_1447993474_189_6.99.py       111915  1447993474         189
# control_111709_1447799253_28_9.23.py        111709  1447799253          28
# control_1114014_1447542037_15_9.84.py      1114014  1447542037          15
# control_120701_1449528383_247_9.58.py       120701  1449528383         247
# control_111901_1447989966_198_9.58.py       111901  1447989966         198
# control_120707_1449528603_29_8.73.py        120707  1449528603          29
# control_111710_1447804583_57_9.84.py        111710  1447804583          57
# control_120715_1449532299_16_10.26.py       120715  1449532299          16
# control_120705_1449527020_43_10.68.py       120705  1449527020          43
# control_120703_1449528725_434_10.78.py      120703  1449528725         434
# control_111713_1447798987_54_10.59.py       111713  1447798987          54
# control_120805_1449614783_167_10.67.py      120805  1449614783         167
# control_120714_1449532723_36_11.5.py        120714  1449532723          36
# control_120724_1449536585_63_12.01.py       120724  1449536585          63
# control_120709_1449530263_168_13.7.py       120709  1449530263         168
# control_120711_1449531795_141_14.21.py      120711  1449531795         141
#
#                                         flog_score  \
# control_1114013_1447540598_291_2.41.py        2.41
# control_1114018_1447545535_7_2.41.py          2.41
# control_111712_1447799453_409_2.41.py         2.41
# control_111902_1447990994_29_3.0.py           3.00
# control_120723_1449536516_19_3.0.py           3.00
# control_120712_1449531512_113_2.61.py         3.29
# control_120722_1449535877_103_2.61.py         3.29
# control_120713_1449531544_24_3.71.py          4.22
# control_120102_1449528822_18_4.1.py           5.73
# control_120802_1449613833_121_6.87.py         6.87
# control_120710_1449531247_183_7.2.py          7.20
# control_120801_1449613421_121_6.99.py         7.54
# control_1114016_1447542994_530_8.05.py        8.29
# control_111904_1447993241_112_7.5.py          8.96
# control_1114012_1447544396_845_8.76.py        9.21
# control_111915_1447993474_189_6.99.py         9.21
# control_111709_1447799253_28_9.23.py          9.44
# control_1114014_1447542037_15_9.84.py         9.84
# control_120701_1449528383_247_9.58.py         9.99
# control_111901_1447989966_198_9.58.py         9.99
# control_120707_1449528603_29_8.73.py         10.01
# control_111710_1447804583_57_9.84.py         10.24
# control_120715_1449532299_16_10.26.py        10.64
# control_120705_1449527020_43_10.68.py        10.68
# control_120703_1449528725_434_10.78.py       10.78
# control_111713_1447798987_54_10.59.py        10.78
# control_120805_1449614783_167_10.67.py       10.85
# control_120714_1449532723_36_11.5.py         12.50
# control_120724_1449536585_63_12.01.py        12.97
# control_120709_1449530263_168_13.7.py        13.30
# control_120711_1449531795_141_14.21.py       14.35
#
#                                                                                      code  \
# control_1114013_1447540598_291_2.41.py  def num_common_letters(goal_word, guess):\n\tr...
# control_1114018_1447545535_7_2.41.py    def num_common_letters(goal_word, guess):\n\tr...
# control_111712_1447799453_409_2.41.py   def num_common_letters(goal_word, guess):\n\tr...
# control_111902_1447990994_29_3.0.py     def num_common_letters(goal_word, guess):\n\tr...
# control_120723_1449536516_19_3.0.py     def num_common_letters(goal_word, guess):\n\tr...
# control_120712_1449531512_113_2.61.py   def num_common_letters(goal_word, guess):\n\tr...
# control_120722_1449535877_103_2.61.py   def num_common_letters(goal_word, guess):\n   ...
# control_120713_1449531544_24_3.71.py    def num_common_letters(goal_word, guess):\n   ...
# control_120102_1449528822_18_4.1.py     def num_common_letters(goal_word, guess):\n\tc...
# control_120802_1449613833_121_6.87.py   def num_common_letters(goal_word, guess):\n\tc...
# control_120710_1449531247_183_7.2.py    def num_common_letters2(string1, string2):\n  ...
# control_120801_1449613421_121_6.99.py   def num_common_letters(goal_word, guess):\n   ...
# control_1114016_1447542994_530_8.05.py  def num_common_letters(goal_word, guess):\n\tc...
# control_111904_1447993241_112_7.5.py    def num_common_letters(goal_word, guess):\n\tc...
# control_1114012_1447544396_845_8.76.py  def num_common_letters(goal_word, guess):\n   ...
# control_111915_1447993474_189_6.99.py   def num_common_letters(goal_word, guess):\n\tg...
# control_111709_1447799253_28_9.23.py    def num_common_letters(goal_word, guess):\n\tc...
# control_1114014_1447542037_15_9.84.py   def num_common_letters(goal_word, guess):\n\tx...
# control_120701_1449528383_247_9.58.py   def num_common_letters_second(x, y):\n    i = ...
# control_111901_1447989966_198_9.58.py   def num_common_letters(goal_word, guess):\n   ...
# control_120707_1449528603_29_8.73.py    def num_common_letters(goal_word, guess):\n\tc...
# control_111710_1447804583_57_9.84.py    def num_common_letters(goal_word, guess):\n\tc...
# control_120715_1449532299_16_10.26.py   def num_common_letters(goal_word, guess):\n   ...
# control_120705_1449527020_43_10.68.py   def num_common_letters(goal_word, guess):\n\tc...
# control_120703_1449528725_434_10.78.py  def num_common_letters(goal_word, guess):\n   ...
# control_111713_1447798987_54_10.59.py   def num_common_letters(goal_word, guess):\n\tl...
# control_120805_1449614783_167_10.67.py  def num_common_letters(goal_word, guess):\n\tw...
# control_120714_1449532723_36_11.5.py    def num_common_letters(goal_word, guess):\n\tg...
# control_120724_1449536585_63_12.01.py   def num_common_letters(first, second):\n\tdef ...
# control_120709_1449530263_168_13.7.py   def num_common_letters(goal_word, guess):\n\tg...
# control_120711_1449531795_141_14.21.py  def num_common_letters(goal_word, guess):\n   ...
#
#                                         sid hints     type
# control_1114013_1447540598_291_2.41.py   67  none  control
# control_1114018_1447545535_7_2.41.py     55  none  control
# control_111712_1447799453_409_2.41.py    71  none  control
# control_111902_1447990994_29_3.0.py      79  none  control
# control_120723_1449536516_19_3.0.py      61  none  control
# control_120712_1449531512_113_2.61.py    51  none  control
# control_120722_1449535877_103_2.61.py    54  none  control
# control_120713_1449531544_24_3.71.py     65  none  control
# control_120102_1449528822_18_4.1.py      66  none  control
# control_120802_1449613833_121_6.87.py    69  none  control
# control_120710_1449531247_183_7.2.py     63  none  control
# control_120801_1449613421_121_6.99.py    77  none  control
# control_1114016_1447542994_530_8.05.py   75  none  control
# control_111904_1447993241_112_7.5.py     53  none  control
# control_1114012_1447544396_845_8.76.py   74  none  control
# control_111915_1447993474_189_6.99.py    58  none  control
# control_111709_1447799253_28_9.23.py     59  none  control
# control_1114014_1447542037_15_9.84.py    76  none  control
# control_120701_1449528383_247_9.58.py    78  none  control
# control_111901_1447989966_198_9.58.py    80  none  control
# control_120707_1449528603_29_8.73.py     64  none  control
# control_111710_1447804583_57_9.84.py     52  none  control
# control_120715_1449532299_16_10.26.py    73  none  control
# control_120705_1449527020_43_10.68.py    62  none  control
# control_120703_1449528725_434_10.78.py   68  none  control
# control_111713_1447798987_54_10.59.py    70  none  control
# control_120805_1449614783_167_10.67.py   57  none  control
# control_120714_1449532723_36_11.5.py     60  none  control
# control_120724_1449536585_63_12.01.py    72  none  control
# control_120709_1449530263_168_13.7.py    56  none  control
# control_120711_1449531795_141_14.21.py   81  none  control

# %%
plt.hist(adf.flog_score)
# Out:
# (array([ 114.,   27.,   32.,   42.,   15.,    3.,    3.,    3.,    1.,    3.]),
#  array([  2.41 ,   4.554,   6.698,   8.842,  10.986,  13.13 ,  15.274,
#          17.418,  19.562,  21.706,  23.85 ]),
#  <a list of 10 Patch objects>)

# %%
adf2 = adf.sort(columns = "flog_score")

# %%
adf3 = adf2.drop_duplicates(subset="student_id")

# %%
plt.hist(adf3.flog_score, bins=20)
plt.show()
plt.hist(cdf3.flog_score, bins=20)
# Out:
# (array([ 5.,  2.,  0.,  1.,  0.,  1.,  0.,  1.,  2.,  1.,  1.,  3.,  4.,
#          3.,  3.,  0.,  1.,  1.,  1.,  1.]),
#  array([  2.41 ,   3.007,   3.604,   4.201,   4.798,   5.395,   5.992,
#           6.589,   7.186,   7.783,   8.38 ,   8.977,   9.574,  10.171,
#          10.768,  11.365,  11.962,  12.559,  13.156,  13.753,  14.35 ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist((cdf3.flog_score, adf3.flog_score), normed = True)
# Out:
# ([array([ 0.18911763,  0.0270168 ,  0.0270168 ,  0.0270168 ,  0.08105041,
#           0.10806722,  0.18911763,  0.08105041,  0.05403361,  0.05403361]),
#   array([ 0.65326633,  0.03350084,  0.01675042,  0.        ,  0.01675042,
#           0.        ,  0.08375209,  0.        ,  0.01675042,  0.01675042])],
#  array([  2.41 ,   3.604,   4.798,   5.992,   7.186,   8.38 ,   9.574,
#          10.768,  11.962,  13.156,  14.35 ]),
#  <a list of 2 Lists of Patches objects>)

# %%
a = plt.hist(cdf3.flog_score, normed = True, histtype = 'step')
b = plt.hist(adf3.flog_score, normed = True, histtype = 'step')

# %%
a
# Out:
# (array([ 0.18911763,  0.0270168 ,  0.0270168 ,  0.0270168 ,  0.08105041,
#          0.10806722,  0.18911763,  0.08105041,  0.05403361,  0.05403361]),
#  array([  2.41 ,   3.604,   4.798,   5.992,   7.186,   8.38 ,   9.574,
#          10.768,  11.962,  13.156,  14.35 ]),
#  <a list of 1 Patch objects>)

# %%
b.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-82ed078d10e8> in <module>()
# ----> 1 b.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %%
f_oneway(a[0],b[0])
# Out:
# (0.0030785377240616385, 0.95636365402409651)
